# %%
from __future__ import division
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np


N = 100
n = 1
xs = np.linspace(0, 1, N)
psi_real = np.sqrt(2) * np.sin(np.pi * n * xs)
psi_imaginary = np.zeros((N))

# %%
plt.plot(xs, psi_real, label='real')
plt.plot(xs, psi_imaginary, 'ro', label='imaginary')
plt.legend(loc=0)

# %%
kappa = 1
omega = 1
delta_x = 1 / N
tau = 0
delta_tau = 0.0001

# %%
def compute_H_r(psi_real):
    H_r = np.zeros(N)
    H_r[1:-1] = 0.5 * (psi_real[1:-1] * 2 - psi_real[:-2] - psi_real[2:]) / delta_x ** 2 + kappa * psi_real[1:-1] * np.sin(omega * tau)
    return H_r

def compute_H_i(psi_imaginary):
    H_i = np.zeros(N)
    H_i[1:-1] = 0.5 * (psi_imaginary[1:-1] * 2 - psi_imaginary[:-2] - psi_imaginary[2:]) / delta_x ** 2 + kappa * psi_imaginary[1:-1] * np.sin(omega * tau)
    return H_i

# %%
H_r
# Out:
# array([ 0.        ,  0.2259018 ,  0.45157615,  0.67679579,  0.90133395,
#         1.12496455,  1.34746241,  1.56860348,  1.7881651 ,  2.0059262 ,
#         2.22166749,  2.43517176,  2.64622401,  2.85461174,  3.06012512,
#         3.26255721,  3.46170418,  3.65736551,  3.84934418,  4.03744689,
#         4.22148424,  4.4012709 ,  4.57662586,  4.74737255,  4.91333903,
#         5.0743582 ,  5.23026791,  5.3809112 ,  5.52613636,  5.66579717,
#         5.799753  ,  5.92786897,  6.05001608,  6.16607134,  6.27591789,
#         6.37944512,  6.47654879,  6.56713112,  6.65110091,  6.7283736 ,
#         6.79887139,  6.8625233 ,  6.91926523,  6.96904004,  7.01179762,
#         7.04749491,  7.07609597,  7.09757201,  7.11190139,  7.11906969,
#         7.11906969,  7.11190139,  7.09757201,  7.07609597,  7.04749491,
#         7.01179762,  6.96904004,  6.91926523,  6.8625233 ,  6.79887139,
#         6.7283736 ,  6.65110091,  6.56713112,  6.47654879,  6.37944512,
#         6.27591789,  6.16607134,  6.05001608,  5.92786897,  5.799753  ,
#         5.66579717,  5.52613636,  5.3809112 ,  5.23026791,  5.0743582 ,
#         4.91333903,  4.74737255,  4.57662586,  4.4012709 ,  4.22148424,
#         4.03744689,  3.84934418,  3.65736551,  3.46170418,  3.26255721,
#         3.06012512,  2.85461174,  2.64622401,  2.43517176,  2.22166749,
#         2.0059262 ,  1.7881651 ,  1.56860348,  1.34746241,  1.12496455,
#         0.90133395,  0.67679579,  0.45157615,  0.2259018 ,  0.        ])

# %%
plt.plot(xs, H_r)
plt.plot(xs, H_i)

# %%
N = 100
n = 1
xs = np.linspace(0, 1, N)
psi_real = np.sqrt(2) * np.sin(np.pi * n * xs)
psi_imaginary = np.zeros((N))

def compute_H_r(psi_real):
    H_r = np.zeros(N)
    H_r[1:-1] = 0.5 * (psi_real[1:-1] * 2 - psi_real[:-2] - psi_real[2:]) / delta_x ** 2 + kappa * psi_real[1:-1] * np.sin(omega * tau)
    return H_r

def compute_H_i(psi_imaginary):
    H_i = np.zeros(N)
    H_i[1:-1] = 0.5 * (psi_imaginary[1:-1] * 2 - psi_imaginary[:-2] - psi_imaginary[2:]) / delta_x ** 2 + kappa * psi_imaginary[1:-1] * np.sin(omega * tau)
    return H_i

# %%
class Simulation(object):
    def __init__(self, tau=0):
        self.N = 100
        self.n = 1
        self.tau = 0
        self.delta_tau = 0.0001
        
        self.kappa = 0
        self.omega = 1.2
        self.xs = np.linspace(0, 1, self.N)
        
        self.delta_x = self.xs[1] - self.xs[0]
        
        self.psi_real = np.sqrt(2) * np.sin(np.pi * self.n * xs)
        self.psi_imaginary = np.zeros((self.N))
        self.H_r = self.compute_H_r(self.psi_real)
        self.H_i = self.compute_H_i(self.psi_imaginary)

    def step(self):
        self.tau += self.delta_tau
        psi_real_half = self.psi_real + self.H_i * self.delta_tau / 2
        self.H_r = self.compute_H_r(psi_real_half)
        self.psi_imaginary = self.psi_imaginary - self.H_r * self.delta_tau
        
        self.H_i = self.compute_H_i(self.psi_imaginary)
        self.psi_real = psi_real_half + self.H_i * self.delta_tau / 2
        return self.psi_real, self.psi_imaginary
    
    def compute_system_parameters(self):
        N = self.delta_x * (np.dot(self.psi_imaginary, self.psi_imaginary) + np.dot(self.psi_real, self.psi_real))        #print('t, N', self.tau, N)
        x = self.delta_x * np.dot(self.xs, (np.power(self.psi_imaginary, 2) + np.power(self.psi_real, 2)))
        
        epsilon = self.delta_x * (np.dot(self.psi_imaginary, H_i) + np.dot(self.psi_real, H_r))
        
        return self.tau, N, x, epsilon
        
    def compute_H_r(self, psi_real):
        H_r = np.zeros(self.N)
        H_r[1:-1] = 0.5 * (psi_real[1:-1] * 2 - psi_real[:-2] - psi_real[2:]) / self.delta_x ** 2 + self.kappa * psi_real[1:-1] * np.sin(self.omega * self.tau)
        return H_r

    def compute_H_i(self, psi_imaginary):
        H_i = np.zeros(self.N)
        H_i[1:-1] = 0.5 * (psi_imaginary[1:-1] * 2 - psi_imaginary[:-2] - psi_imaginary[2:]) / self.delta_x ** 2 + self.kappa * psi_imaginary[1:-1] * np.sin(self.omega * self.tau)
        return H_i

# %%
def run_simulation():
    reals = []
    imaginaries = []
    taus = []
    ns = []
    x_means = []
    epsilons = []

    simulation = Simulation()
    for y in range(100):
        for x in range(500):
            psi_real, psi_imaginary = simulation.step()
        t, N, x, epsilon = simulation.compute_system_parameters()
        taus.append(t)
        ns.append(n)
        x_means.append(x)
        epsilons.append(epsilon)
        reals.append(psi_real)
        imaginaries.append(psi_imaginary)


    plt.figure()
    plt.title(r'Real part of $\Psi$')
    for psi in reals:
        plt.plot(xs, psi)

    plt.figure()
    plt.title(r'Imaginary part of $\Psi$')
    for psi in imaginaries:
        plt.plot(xs, psi)
    plt.figure()
    plt.plot(taus, ns)
    plt.title('N(t)')
    plt.figure()
    plt.plot(taus, x_means)
    plt.title('x(t)')
    plt.figure()
    plt.plot(taus, epsilons)
    plt.title(r'$\epsilon(t)$')

# %%
run_simulation()
